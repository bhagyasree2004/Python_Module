# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagyasree2004/Python_Module/blob/main/Python_Module_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10.5
type(a)
# Out:
# float

# %%
a="helo"
type(a)
# Out:
# str

# %%
a=10
type(a)
# Out:
# int

# %%
a=100.0005
type(a)
# Out:
# float

# %%
a = "10"
b = int(a)

print(b)
print(type(b))
# Out:
# 10
# <class 'int'>

# %%
a = 12.8
b = int(a)

print(b)
# Out:
# 12

# %%
a = 100
b = str(a)

print(b)
print(type(b))
# Out:
# 100
# <class 'str'>

# %%
a = "45.75"
b = float(a)

print(b)
print(type(b))
# Out:
# 45.75
# <class 'float'>

# %%
a = 25
b = float(a)

print(b)
print(type(b))
# Out:
# 25.0
# <class 'float'>

# %%
word = "Hello"

for ch in word:
    print(ch, ord(ch))
# Out:
# H 72
# e 101
# l 108
# l 108
# o 111

# %%
print(chr(97))
# Out:
# a

# %%
print(ord('H'))
# Out:
# 72

# %%
A=10
print(A)
# Out:
# 10

# %%
a=10
print(a)
# Out:
# 10

# %%
1a=10
print(1a)
# Out:
#   File "/tmp/ipykernel_3482/1979829741.py", line 1
#     1a=10
#     ^
# SyntaxError: invalid decimal literal

# %%
tuple=(1,2,3,4)
tuples=1,2,3,4
print(tuple)
print(tuples)
# Out:
# (1, 2, 3, 4)
# (1, 2, 3, 4)

# %%
Tuples=(1,2,3,4,[5,6])
print(Tuples)
# Out:
# (1, 2, 3, 4, [5, 6])

# %%
name=input('Enter your name')
print(name)
# Out:
# Enter your nameBhagya sree
# Bhagya sree

# %%
name
# Out:
# 'Bhagya sree'

# %%
a=[10,20,30]
type(a)
# Out:
# list

# %%
a=(10,20,30)
type(a)
# Out:
# tuple

# %%
A=10
print(A)
b=20
print(b)
# Out:
# 10
# 20

# %%
string_var='Hello'
string_var[-2]


string_vars="Hello"
string_vars[0]
# Out:
# 'H'

# %%
word = "Hello"

new_word = word.replace("H", "Y")

print(new_word)
# Out:
# Yello

# %%
a='hello'
a[-2]


b='hello'
b[0]
# Out:
# 'h'

# %%
 word = "Hello"

word[0] = "Y"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/4166884207.py in <cell line: 0>()
#       1 word = "Hello"
#       2
# ----> 3 word[0] = "Y"
#
# TypeError: 'str' object does not support item assignment

# %%
word = "Hello"

chars = list(word)

chars[0] = "Y"

new_word = "".join(chars)

print(new_word)

a=chars[1]
b=chars[-2]
print(a)
print(b)
# Out:
# Yello
# e
# l

# %%
#tuples,list,numbers,string,sets,dictionary

# %%
a=5.5
b='5'
print(a+int(b))
print(a+float(b))
print(a+int(float(b)))

print(int(a)+int(float(b)))
# Out:
# 10.5
# 10.5
# 10.5
# 10

# %%
a=10
b=8
a**b
# Out:
# 100000000

# %%
#addition
a=10
b=20
print(a+b)
# Out:
# 30

# %%
#subtraction
a=10
b=20
print(a-b)
# Out:
# -10

# %%
#multiplication
a=10
b=20
print(a*b)
# Out:
# 200

# %%
#division
a=10
b=20
print( a/b)
# Out:
# 0.5

# %%
#floor
a=10
b=20
print( a//b)
# Out:
# 0

# %%
#reminder
a=10
b=2
print(a%b)
# Out:
# 0

# %%
a=10
b=20
print(a**b)
# Out:
# 100000000000000000000

# %%
a=10
b=10
print((a+b),(a-b))
# Out:
# 20 0

# %%
a=10
b=2
print((a//b),(a%b),(a/b))
# Out:
# 5 0 5.0

# %%
print(4+(8**2)-3**2%1)
# Out:
# 68

# %%
#bodmass
print(4%(1+9)**2-60//(7+2))

(4%(10)**2-60//(9))
(4%10**2-60//9)
(4%100-60//9)
(4-60//9)
(4-6)
(-2)
# Out:
# -2
# -2

# %%
2//5
# Out:
# 0

# %%
10//9
# Out:
# 1

# %%
#list
a=10
print(type(a))
a=[10,20,30]
print(type(a))
len(a)
list2[-1][0][-6:-3]

# %%
from typing import Concatenate
name="bhagya"
names="sree"

c=name + " "+ names
print(c)
# Out:
# bhagya sree

# %%
list1=[1,2,3,4]
list2=[5,6,7,8]
list3=list1+list2
print(list3)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
list4=[1,2,3,4]
new_list=list4+[5,6]
print(new_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#split the string input_str='kumar_Ravi_003' to the persons second name,first name ,second_name='kumar',first_name='ravi',customer_code='003'
input_str='Kumar_Ravi_003'
first_name,second_name,customer_code=input_str.split("_")
print(first_name)
print(second_name)
print(customer_code)
# Out:
# Kumar
# Ravi
# 003

# %%
list_1=[2,33,222,14,25]
list_1[-5]
# Out:
# 2

# %%
I Lost Everything
word=['1','2','3','4']
word[:]=[]
print(word)
# Out:
# []

# %%
a=[1,2,3,(12,13)]
print(a)
# Out:
# [1, 2, 3, (12, 13)]

# %%
a=(1,2,3,[4,5])
print(a)
# Out:
# (1, 2, 3, [4, 5])

# %%
L=['one','two','three','four','five','six']
print(sorted(L))
print(L)
# Out:
# ['five', 'four', 'one', 'six', 'three', 'two']
# ['one', 'two', 'three', 'four', 'five', 'six']
